# %%
import imageio

# %%
from skimage import data

# %%
img_gray = data.camera()

# %%
print(type(img_gray))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img_gray.shape)
# Out:
# (512, 512)

# %%
print(img_gray.dtype)
# Out:
# uint8

# %%
img_gray.ndim
# Out:
# 2

# %%
print(img_gray.min(), img_gray.max(), img_gray.mean(), img_gray.std())
# Out:
# 0 255 118.31400299072266 61.9960435760992

# %%
print('%d, %d, %.2f, %.2f' % (img_gray.min(), img_gray.max(), img_gray.mean(), img_gray.std()))
# Out:
# 0, 255, 118.31, 62.00

# %%
print(img_gray)
# Out:
# [[156 157 160 ... 152 152 152]
#  [156 157 159 ... 152 152 152]
#  [158 157 156 ... 152 152 152]
#  ...
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img_gray)
plt.colorbar()

# %%
plt.imshow(img_gray, cmap='gray')
plt.colorbar()
